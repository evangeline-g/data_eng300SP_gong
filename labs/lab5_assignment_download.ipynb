# %% [markdown]
# ### Start Spark Session

# %%
import pyspark 
print(pyspark.__version__)
# Out:
# 4.1.1

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("PySparkTutorial") \
    .getOrCreate()

spark.range(5).show()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/14 21:00:54 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# +---+
# | id|
# +---+
# |  0|
# |  1|
# |  2|
# |  3|
# |  4|
# +---+

# %% [markdown]
# ### Test creating RDD

# %%
spark = SparkSession.builder.getOrCreate()

sc = spark.sparkContext

rdd = sc.parallelize([1, 2, 3, 4, 5])
rdd.collect()
# Out:
# [1, 2, 3, 4, 5]

# %%
rdd2 = rdd.map(lambda x: x * 10)   # no computation yet
rdd2.take(3)
# Out:
# [10, 20, 30]

# %% [markdown]
# ## ML example with a real dataset
# For most ML algorithm within PySpark, they are not classic MapReduce.
#
# Classic MapReduce means you structure the whole job as:
# ```
# map → shuffle/group-by key → reduce
# (one or a small fixed number of stages; batch; heavy “shuffle then reduce” pattern)
# ```
#
# Machine learning models are typically done with an iterative optimization algorithm (e.g., gradient-based methods or solvers that repeatedly update parameters). That workflow looks more like:
# ```
# repeat until convergence:
# compute gradients/statistics over data in parallel → aggregate → update weights
# ```
#
# Spark executes this as a DAG of transformations and actions, possibly with caching, and can run many stages across iterations.

# %%
from typing import List, Tuple

from pyspark.sql import SparkSession, DataFrame
from pyspark.sql import functions as F
from pyspark.sql.window import Window
from pyspark.ml.feature import VectorAssembler

# %%
# ----------------------------
# 1) Spark session
# ----------------------------
def start_spark(app_name: str = "LD2011_2014_pipeline") -> SparkSession:
    """
    Start (or get) a SparkSession. Adjust configs here if needed.
    """
    spark = (
        SparkSession.builder
        .appName(app_name)
        .master("local[*]")   # optional: comment out if you're on a cluster
        .getOrCreate()
    )
    spark.sparkContext.setLogLevel("WARN")
    return spark

# %%
# ----------------------------
# 2) Read + parse wide format
# ----------------------------
def read_ld_wide(
    spark: SparkSession,
    raw_path: str,
    sep: str = ";",
) -> DataFrame:
    """
    Read the UCI LD2011_2014.txt as a wide CSV-like file.
    """
    return (
        spark.read
        .option("sep", sep)
        .option("header", False)
        .option("inferSchema", False)
        .csv(raw_path)
    )

# %%
def rename_and_parse_timestamp(df_wide: DataFrame) -> DataFrame:
    """
    Rename columns to ts_raw + MT_001..MT_370 and parse timestamp.
    """
    n = len(df_wide.columns)  # should be 371 for LD2011_2014
    new_cols = ["ts_raw"] + [f"MT_{i:03d}" for i in range(1, n)]
    df_wide = df_wide.toDF(*new_cols)

    df = (
        df_wide
        .withColumn("ts", F.to_timestamp("ts_raw", "yyyy-MM-dd HH:mm:ss"))
        .drop("ts_raw")
        .dropna(subset=["ts"])
    )
    return df

# %%
def cast_meter_columns_to_double(df: DataFrame) -> Tuple[DataFrame, List[str]]:
    """
    Convert meter columns to double, handling comma decimals. Returns (df, meter_cols).
    """
    meter_cols = [c for c in df.columns if c != "ts"]
    for c in meter_cols:
        df = df.withColumn(
            c,
            F.expr(f"try_cast(regexp_replace(`{c}`, ',', '.') as double)")
        )
    return df, meter_cols

# %%
# ----------------------------
# 3) Wide -> long
# ----------------------------
def wide_to_long(df: DataFrame, meter_cols: List[str]) -> DataFrame:
    """
    Convert wide meter columns into long format: (ts, client_id, y).
    """
    stack_expr = ", ".join([f"'{c}', `{c}`" for c in meter_cols])
    df_long = (
        df.selectExpr(
            "ts",
            f"stack({len(meter_cols)}, {stack_expr}) as (client_id, y)"
        )
        .dropna(subset=["ts", "y"])
    )
    return df_long

# %%
def sample_clients(df_long: DataFrame, k: int = 3, seed: int = 42) -> List[str]:
    """
    Pick k distinct clients. Uses deterministic order; you can also randomize if you want.
    """
    # Deterministic: orderBy client_id then take k
    rows = (
        df_long.select("client_id")
        .distinct()
        .orderBy("client_id")
        .limit(k)
        .collect()
    )
    return [r["client_id"] for r in rows]

# %%
def filter_clients(df_long: DataFrame, clients: List[str]) -> DataFrame:
    return df_long.filter(F.col("client_id").isin(clients))# ----------------------------
# 4) Feature engineering (window)
# ----------------------------
def build_features(df_small: DataFrame) -> DataFrame:
    """
    Create lag/rolling/time features and label using lead().
    """
    w = Window.partitionBy("client_id").orderBy("ts")

    df_feat = (
        df_small
        .withColumn("y_next", F.lead("y", 1).over(w))     # label
        .withColumn("lag1",  F.lag("y", 1).over(w))
        .withColumn("lag4",  F.lag("y", 4).over(w))
        .withColumn("lag96", F.lag("y", 96).over(w))
        .withColumn("roll4_mean",  F.avg("y").over(w.rowsBetween(-4, -1)))
        .withColumn("roll96_mean", F.avg("y").over(w.rowsBetween(-96, -1)))
        .withColumn("hour", F.hour("ts"))
        .withColumn("dow",  F.dayofweek("ts"))
        .dropna(subset=["y_next", "lag1", "lag4", "lag96", "roll4_mean", "roll96_mean"])
        .withColumnRenamed("y_next", "label")
    )
    return df_feat

# %%
def add_baselines(df_feat: DataFrame) -> DataFrame:
    """
    Add naive and seasonal baseline predictions.
    """
    return (
        df_feat
        .withColumn("pred_naive", F.col("lag1"))
        .withColumn("pred_seasonal", F.col("lag96"))
    )

# %%
# ----------------------------
# 5) Train/test split + assemble
# ----------------------------
def train_test_split_by_ts(df: DataFrame, cutoff: str = "2014-01-01 00:00:00") -> Tuple[DataFrame, DataFrame]:
    cutoff_ts = F.to_timestamp(F.lit(cutoff))
    train = df.filter(F.col("ts") < cutoff_ts)
    test  = df.filter(F.col("ts") >= cutoff_ts)
    return train, test

# %%
def assemble_features(
    train: DataFrame,
    test: DataFrame,
    feature_cols: List[str],
    features_col: str = "features"
) -> Tuple[DataFrame, DataFrame]:
    assembler = VectorAssembler(inputCols=feature_cols, outputCol=features_col)
    train_ml = assembler.transform(train).select("ts", "client_id", features_col, "label")
    test_ml  = assembler.transform(test).select("ts", "client_id", features_col, "label")
    return train_ml, test_ml

# %%
def run_pipeline(raw_path: str, k_clients: int = 3) -> Tuple[DataFrame, DataFrame]:
    spark = start_spark()

    df_wide = read_ld_wide(spark, raw_path)
    df = rename_and_parse_timestamp(df_wide)
    df, meter_cols = cast_meter_columns_to_double(df)

    # (optional sanity check)
    df.select("ts", meter_cols[0]).show(5, truncate=False)

    df_long = wide_to_long(df, meter_cols)
    df_long.show(5, truncate=False)

    clients = sample_clients(df_long, k=k_clients)
    df_small = filter_clients(df_long, clients)

    df_feat = build_features(df_small)
    df_base = add_baselines(df_feat)

    train, test = train_test_split_by_ts(df_base, cutoff="2012-06-01 00:00:00")

    feature_cols = ["lag1", "lag4", "lag96", "roll4_mean", "roll96_mean", "hour", "dow"]
    train_ml, test_ml = assemble_features(train, test, feature_cols)

    return train_ml, test_ml

# %%
import os, shutil

src = f"LD2011_2014.txt"
dst = f"/tmp/LD2011_2014.txt"

shutil.copyfile(src, dst)
raw_path = os.path.abspath(dst)

train_ml, test_ml = run_pipeline(raw_path, k_clients=3)

train_ml.show(5, truncate=False)
test_ml.show(5, truncate=False)
# Out:
# 26/05/14 21:01:09 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# +-------------------+------+
# |ts                 |MT_001|
# +-------------------+------+
# |2011-01-01 00:15:00|0.0   |
# |2011-01-01 00:30:00|0.0   |
# |2011-01-01 00:45:00|0.0   |
# |2011-01-01 01:00:00|0.0   |
# |2011-01-01 01:15:00|0.0   |
# +-------------------+------+
# only showing top 5 rows
# 26/05/14 21:01:38 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +-------------------+---------+---+
# |ts                 |client_id|y  |
# +-------------------+---------+---+
# |2011-01-01 00:15:00|MT_001   |0.0|
# |2011-01-01 00:15:00|MT_002   |0.0|
# |2011-01-01 00:15:00|MT_003   |0.0|
# |2011-01-01 00:15:00|MT_004   |0.0|
# |2011-01-01 00:15:00|MT_005   |0.0|
# +-------------------+---------+---+
# only showing top 5 rows
# +-------------------+---------+-------------------+-----+
# |ts                 |client_id|features           |label|
# +-------------------+---------+-------------------+-----+
# |2011-01-02 00:15:00|MT_001   |(7,[6],[1.0])      |0.0  |
# |2011-01-02 00:30:00|MT_001   |(7,[6],[1.0])      |0.0  |
# |2011-01-02 00:45:00|MT_001   |(7,[6],[1.0])      |0.0  |
# |2011-01-02 01:00:00|MT_001   |(7,[5,6],[1.0,1.0])|0.0  |
# |2011-01-02 01:15:00|MT_001   |(7,[5,6],[1.0,1.0])|0.0  |
# +-------------------+---------+-------------------+-----+
# only showing top 5 rows
# +-------------------+---------+------------------------------------------------------------------------------------------------+----------------+
# |ts                 |client_id|features                                                                                        |label           |
# +-------------------+---------+------------------------------------------------------------------------------------------------+----------------+
# |2012-06-01 00:00:00|MT_001   |[8.88324873096447,17.7664974619289,2.53807106598985,13.007614213197959,8.36770304568528,0.0,6.0]|5.0761421319797 |
# |2012-06-01 00:15:00|MT_001   |[3.80710659898477,8.88324873096447,2.53807106598985,9.517766497461926,8.380922165820646,0.0,6.0]|3.80710659898477|
# |2012-06-01 00:30:00|MT_001   |[5.0761421319797,16.497461928934,2.53807106598985,8.565989847715734,8.407360406091376,0.0,6.0]  |5.0761421319797 |
# |2012-06-01 00:45:00|MT_001   |[3.80710659898477,8.88324873096447,3.80710659898477,5.393401015228427,8.420579526226739,0.0,6.0]|5.0761421319797 |
# |2012-06-01 01:00:00|MT_001   |[5.0761421319797,3.80710659898477,2.53807106598985,4.441624365482235,8.433798646362103,1.0,6.0] |3.80710659898477|
# +-------------------+---------+------------------------------------------------------------------------------------------------+----------------+
# only showing top 5 rows

# %%
import math
from pyspark.sql import DataFrame
from pyspark.sql import functions as F


def evaluate_predictions(
    df: DataFrame,
    label_col: str = "label",
    pred_cols: List[str] = None,
    group_col: str = None,
) -> DataFrame:
    """
    Evaluate one or multiple prediction columns against label.
    Returns a Spark DataFrame with metrics for each pred column.
    
    Metrics: n, MAE, RMSE
    If group_col is provided (e.g., 'client_id'), metrics are computed per group.
    """
    if pred_cols is None:
        pred_cols = []

    if not pred_cols:
        raise ValueError("pred_cols must include at least one prediction column name.")

    # create a long form: (group?, pred_name, label, pred)
    select_cols = []
    if group_col:
        select_cols.append(group_col)

    # stack: 'pred_naive', pred_naive, 'pred_seasonal', pred_seasonal, ...
    stack_expr = ", ".join([f"'{c}', `{c}`" for c in pred_cols])

    df_long = (
        df.select(
            *(select_cols + [F.col(label_col).alias("label")])
        )
        .selectExpr(
            *(select_cols + ["label",
                             f"stack({len(pred_cols)}, {stack_expr}) as (pred_name, pred)"])
        )
        .dropna(subset=["label", "pred"])
    )

    # metrics
    err = (F.col("pred") - F.col("label"))
    agg_exprs = [
        F.count(F.lit(1)).alias("n"),
        F.avg(F.abs(err)).alias("mae"),
        F.sqrt(F.avg(err * err)).alias("rmse"),
    ]

    if group_col:
        out = df_long.groupBy(group_col, "pred_name").agg(*agg_exprs).orderBy(group_col, "pred_name")
    else:
        out = df_long.groupBy("pred_name").agg(*agg_exprs).orderBy("pred_name")

    return out

# %% [markdown]
# ### Implement the ML models

# %%
from pyspark.ml.evaluation import RegressionEvaluator

# %% [markdown]
# ### Model A: Linear Regression (strong baseline)

# %%
from pyspark.ml.regression import LinearRegression

lr = LinearRegression(featuresCol="features", labelCol="label")
lr_model = lr.fit(train_ml)
pred_lr = lr_model.transform(test_ml).withColumnRenamed("prediction", "pred_lr")
# Out:
# 26/05/14 21:11:53 WARN Instrumentation: [5536d46a] regParam is zero, which might cause numerical instability and overfitting.

# %%
rmse_eval = RegressionEvaluator(labelCol="label", predictionCol="pred_lr", metricName="rmse")
mae_eval  = RegressionEvaluator(labelCol="label", predictionCol="pred_lr", metricName="mae")
r2_eval   = RegressionEvaluator(labelCol="label", predictionCol="pred_lr", metricName="r2")

rmse_lr = rmse_eval.evaluate(pred_lr)
mae_lr  = mae_eval.evaluate(pred_lr)
r2_lr   = r2_eval.evaluate(pred_lr)

print(f"LR test RMSE: {rmse_lr:.4f}")
print(f"LR test MAE : {mae_lr:.4f}")
print(f"LR test R2  : {r2_lr:.4f}")
# Out:
# [Stage 72:>                                                         (0 + 1) / 1]
# LR test RMSE: 2.1012
# LR test MAE : 0.9658
# LR test R2  : 0.9723

# %% [markdown]
# ### Model B: Gradient Boost Tree

# %%
from pyspark.ml.regression import GBTRegressor

gbt = GBTRegressor(featuresCol="features", labelCol="label", maxDepth=8, seed=42)
gbt_model = gbt.fit(train_ml)
pred_gbt = gbt_model.transform(test_ml).withColumnRenamed("prediction", "pred_gbt")
# Out:
# 26/05/14 21:25:38 WARN DAGScheduler: Broadcasting large task binary with size 1014.5 KiB
# 26/05/14 21:25:39 WARN DAGScheduler: Broadcasting large task binary with size 1016.6 KiB
# 26/05/14 21:25:39 WARN DAGScheduler: Broadcasting large task binary with size 1017.1 KiB
# 26/05/14 21:25:39 WARN DAGScheduler: Broadcasting large task binary with size 1017.7 KiB
# 26/05/14 21:25:39 WARN DAGScheduler: Broadcasting large task binary with size 1018.9 KiB
# 26/05/14 21:25:39 WARN DAGScheduler: Broadcasting large task binary with size 1021.2 KiB
# 26/05/14 21:25:39 WARN DAGScheduler: Broadcasting large task binary with size 1025.8 KiB
# 26/05/14 21:25:40 WARN DAGScheduler: Broadcasting large task binary with size 1034.5 KiB
# 26/05/14 21:25:40 WARN DAGScheduler: Broadcasting large task binary with size 1049.6 KiB
# 26/05/14 21:25:40 WARN DAGScheduler: Broadcasting large task binary with size 1050.9 KiB
# 26/05/14 21:25:40 WARN DAGScheduler: Broadcasting large task binary with size 1051.4 KiB
# 26/05/14 21:25:40 WARN DAGScheduler: Broadcasting large task binary with size 1051.9 KiB
# 26/05/14 21:25:41 WARN DAGScheduler: Broadcasting large task binary with size 1053.1 KiB
# 26/05/14 21:25:41 WARN DAGScheduler: Broadcasting large task binary with size 1055.4 KiB
# 26/05/14 21:25:41 WARN DAGScheduler: Broadcasting large task binary with size 1060.0 KiB
# 26/05/14 21:25:41 WARN DAGScheduler: Broadcasting large task binary with size 1068.8 KiB
# 26/05/14 21:25:41 WARN DAGScheduler: Broadcasting large task binary with size 1084.8 KiB
# 26/05/14 21:25:41 WARN DAGScheduler: Broadcasting large task binary with size 1086.7 KiB
# 26/05/14 21:25:42 WARN DAGScheduler: Broadcasting large task binary with size 1087.2 KiB
# 26/05/14 21:25:42 WARN DAGScheduler: Broadcasting large task binary with size 1087.8 KiB
# 26/05/14 21:25:42 WARN DAGScheduler: Broadcasting large task binary with size 1088.9 KiB
# 26/05/14 21:25:42 WARN DAGScheduler: Broadcasting large task binary with size 1091.2 KiB
# 26/05/14 21:25:42 WARN DAGScheduler: Broadcasting large task binary with size 1095.8 KiB
# 26/05/14 21:25:42 WARN DAGScheduler: Broadcasting large task binary with size 1104.5 KiB
# 26/05/14 21:25:42 WARN DAGScheduler: Broadcasting large task binary with size 1119.8 KiB
# 26/05/14 21:25:42 WARN DAGScheduler: Broadcasting large task binary with size 1120.9 KiB
# 26/05/14 21:25:43 WARN DAGScheduler: Broadcasting large task binary with size 1121.3 KiB
# 26/05/14 21:25:43 WARN DAGScheduler: Broadcasting large task binary with size 1121.9 KiB
# 26/05/14 21:25:43 WARN DAGScheduler: Broadcasting large task binary with size 1123.1 KiB
# 26/05/14 21:25:43 WARN DAGScheduler: Broadcasting large task binary with size 1125.4 KiB
# 26/05/14 21:25:43 WARN DAGScheduler: Broadcasting large task binary with size 1130.0 KiB
# 26/05/14 21:25:43 WARN DAGScheduler: Broadcasting large task binary with size 1139.1 KiB
# 26/05/14 21:25:44 WARN DAGScheduler: Broadcasting large task binary with size 1155.9 KiB
# 26/05/14 21:25:44 WARN DAGScheduler: Broadcasting large task binary with size 1158.0 KiB
# 26/05/14 21:25:44 WARN DAGScheduler: Broadcasting large task binary with size 1158.5 KiB
# 26/05/14 21:25:44 WARN DAGScheduler: Broadcasting large task binary with size 1159.1 KiB
# 26/05/14 21:25:44 WARN DAGScheduler: Broadcasting large task binary with size 1160.3 KiB
# 26/05/14 21:25:44 WARN DAGScheduler: Broadcasting large task binary with size 1162.6 KiB
# 26/05/14 21:25:45 WARN DAGScheduler: Broadcasting large task binary with size 1166.9 KiB
# 26/05/14 21:25:45 WARN DAGScheduler: Broadcasting large task binary with size 1174.8 KiB
# 26/05/14 21:25:45 WARN DAGScheduler: Broadcasting large task binary with size 1189.5 KiB
# 26/05/14 21:25:45 WARN DAGScheduler: Broadcasting large task binary with size 1191.3 KiB
# 26/05/14 21:25:45 WARN DAGScheduler: Broadcasting large task binary with size 1191.8 KiB
# 26/05/14 21:25:45 WARN DAGScheduler: Broadcasting large task binary with size 1192.4 KiB
# 26/05/14 21:25:46 WARN DAGScheduler: Broadcasting large task binary with size 1193.6 KiB
# 26/05/14 21:25:46 WARN DAGScheduler: Broadcasting large task binary with size 1195.3 KiB
# 26/05/14 21:25:46 WARN DAGScheduler: Broadcasting large task binary with size 1198.5 KiB
# 26/05/14 21:25:46 WARN DAGScheduler: Broadcasting large task binary with size 1204.8 KiB
# 26/05/14 21:25:46 WARN DAGScheduler: Broadcasting large task binary with size 1217.4 KiB
# 26/05/14 21:25:46 WARN DAGScheduler: Broadcasting large task binary with size 1219.8 KiB
# 26/05/14 21:25:47 WARN DAGScheduler: Broadcasting large task binary with size 1220.3 KiB
# 26/05/14 21:25:47 WARN DAGScheduler: Broadcasting large task binary with size 1220.8 KiB
# 26/05/14 21:25:47 WARN DAGScheduler: Broadcasting large task binary with size 1222.0 KiB
# 26/05/14 21:25:47 WARN DAGScheduler: Broadcasting large task binary with size 1224.3 KiB
# 26/05/14 21:25:47 WARN DAGScheduler: Broadcasting large task binary with size 1228.9 KiB
# 26/05/14 21:25:47 WARN DAGScheduler: Broadcasting large task binary with size 1237.7 KiB
# 26/05/14 21:25:48 WARN DAGScheduler: Broadcasting large task binary with size 1253.8 KiB
# 26/05/14 21:25:48 WARN DAGScheduler: Broadcasting large task binary with size 1256.0 KiB
# 26/05/14 21:25:48 WARN DAGScheduler: Broadcasting large task binary with size 1256.4 KiB
# 26/05/14 21:25:48 WARN DAGScheduler: Broadcasting large task binary with size 1257.0 KiB
# 26/05/14 21:25:48 WARN DAGScheduler: Broadcasting large task binary with size 1258.2 KiB
# 26/05/14 21:25:48 WARN DAGScheduler: Broadcasting large task binary with size 1260.2 KiB
# 26/05/14 21:25:49 WARN DAGScheduler: Broadcasting large task binary with size 1264.3 KiB
# 26/05/14 21:25:49 WARN DAGScheduler: Broadcasting large task binary with size 1271.9 KiB
# 26/05/14 21:25:49 WARN DAGScheduler: Broadcasting large task binary with size 1286.5 KiB

# %%
rmse_eval = RegressionEvaluator(labelCol="label", predictionCol="pred_gbt", metricName="rmse")
mae_eval  = RegressionEvaluator(labelCol="label", predictionCol="pred_gbt", metricName="mae")
r2_eval   = RegressionEvaluator(labelCol="label", predictionCol="pred_gbt", metricName="r2")

rmse_gbt = rmse_eval.evaluate(pred_gbt)
mae_gbt  = mae_eval.evaluate(pred_gbt)
r2_gbt   = r2_eval.evaluate(pred_gbt)

print(f"GBT test RMSE: {rmse_gbt:.4f}")
print(f"GBT test MAE : {mae_gbt:.4f}")
print(f"GBT test R2  : {r2_gbt:.4f}")
# Out:
# [Stage 579:>                                                        (0 + 1) / 1]
# GBT test RMSE: 5.7429
# GBT test MAE : 2.1745
# GBT test R2  : 0.7931

# %% [markdown]
# ### Model C: Random Forest

# %%
from pyspark.ml.regression import RandomForestRegressor

rf = RandomForestRegressor(featuresCol="features", labelCol="label", numTrees=50, maxDepth=8, seed=42)
rf_model = rf.fit(train_ml)
pred_rf = rf_model.transform(test_ml).withColumnRenamed("prediction","pred_rf")
# Out:
# 26/05/14 21:05:28 WARN DAGScheduler: Broadcasting large task binary with size 1076.6 KiB
# 26/05/14 21:05:30 WARN DAGScheduler: Broadcasting large task binary with size 1502.8 KiB
# 26/05/14 21:05:32 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB

# %%
rmse_eval = RegressionEvaluator(labelCol="label", predictionCol="pred_rf", metricName="rmse")
mae_eval  = RegressionEvaluator(labelCol="label", predictionCol="pred_rf", metricName="mae")
r2_eval   = RegressionEvaluator(labelCol="label", predictionCol="pred_rf", metricName="r2")

rmse = rmse_eval.evaluate(pred_rf)
mae  = mae_eval.evaluate(pred_rf)
r2   = r2_eval.evaluate(pred_rf)

print(f"RF test RMSE: {rmse:.4f}")
print(f"RF test MAE : {mae:.4f}")
print(f"RF test R2  : {r2:.4f}")
# Out:
# [Stage 56:>                                                         (0 + 1) / 1]
# LR test RMSE: 5.0428
# LR test MAE : 2.0511
# LR test R2  : 0.8404
